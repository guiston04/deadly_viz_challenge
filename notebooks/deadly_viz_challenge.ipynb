# %% [markdown]
# # Deadly Visualizations!!!
#
# ![Image](../images/viz_types_portada.png)

# %% [markdown]
# ## Setup
#
# First we need to create a basic setup which includes:
#
# - Importing the libraries.
#
# - Reading the dataset file (source [Instituto Nacional de Estadística](https://www.ine.es/ss/Satellite?L=es_ES&c=Page&cid=1259942408928&p=1259942408928&pagename=ProductosYServicios%2FPYSLayout)).
#
# - Create a couple of columns and tables for the analysis.
#
# __NOTE:__ some functions were already created in order to help you go through the challenge. However, feel free to perform any code you might need.

# %%
# imports

import sys
import re
sys.path.insert(0, "../modules")

import numpy as np
import pandas as pd

import plotly.express as px
import cufflinks as cf
cf.go_offline()

import module as mod     # functions are include in module.py
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# read dataset

deaths = pd.read_csv('../data/7947.csv', sep=';', thousands='.')

deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301158 entries, 0 to 301157
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Causa de muerte  301158 non-null  object
#  1   Sexo             301158 non-null  object
#  2   Edad             301158 non-null  object
#  3   Periodo          301158 non-null  int64
#  4   Total            301158 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 11.5+ MB

# %%
# add some columns...you'll need them later

deaths['cause_code'] = deaths['Causa de muerte'].apply(mod.cause_code)
deaths['cause_group'] = deaths['Causa de muerte'].apply(mod.cause_types)
deaths['cause_name'] = deaths['Causa de muerte'].apply(mod.cause_name)

deaths.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301158 entries, 0 to 301157
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Causa de muerte  301158 non-null  object
#  1   Sexo             301158 non-null  object
#  2   Edad             301158 non-null  object
#  3   Periodo          301158 non-null  int64
#  4   Total            301158 non-null  int64
#  5   cause_code       301158 non-null  object
#  6   cause_group      301158 non-null  object
#  7   cause_name       301158 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 18.4+ MB

# %%
# lets check the categorical variables

var_list = ['Sexo', 'Edad', 'Periodo', 'cause_code', 'cause_name', 'cause_group']

categories = mod.cat_var(deaths, var_list)
categories
# Out:
#   categorical_variable  number_of_possible_values  \
# 0           cause_code                        117
# 1           cause_name                        117
# 2              Periodo                         39
# 3                 Edad                         22
# 4                 Sexo                          3
# 5          cause_group                          2
#
#                                               values
# 0  [001-102, 001-008, 001, 002, 003, 004, 005, 00...
# 1  [I-XXII.Todas las causas, I.Enfermedades infec...
# 2  [2018, 2017, 2016, 2015, 2014, 2013, 2012, 201...
# 3  [Todas las edades, Menos de 1 año, De 1 a 4 añ...
# 4                          [Total, Hombres, Mujeres]
# 5                    [Multiple causes, Single cause]

# %%
# we need also to create a causes table for the analysis

causes_table = deaths[['cause_code', 'cause_name']].drop_duplicates().sort_values(by='cause_code').reset_index(drop=True)

causes_table
# Out:
#     cause_code                                         cause_name
# 0          001              Enfermedades infecciosas intestinales
# 1      001-008          I.Enfermedades infecciosas y parasitarias
# 2      001-102                            I-XXII.Todas las causas
# 3          002                 Tuberculosis y sus efectos tardíos
# 4          003                           Enfermedad meningocócica
# ..         ...                                                ...
# 112        098                 Suicidio y lesiones autoinfligidas
# 113        099                             Agresiones (homicidio)
# 114        100                Eventos de intención no determinada
# 115        101  Complicaciones de la atención médica y quirúrgica
# 116        102        Otras causas externas y sus efectos tardíos
#
# [117 rows x 2 columns]

# %%
# And some space for free-style Pandas!!! (e.g.: df['column_name'].unique())


death_df = deaths[(deaths.cause_group == "Multiple causes") & (deaths.cause_name != "I-XXII.Todas las causas")]
death_df["cause_name"].unique()

death = death_df[death_df.Periodo < 1996]


death = death[death.Periodo < 1987]

# %%
poblacion_df = pd.read_csv("/Users/guillaumedieude/Desktop/ironhack/curso/Los_Challenges/challenge_deaths/deadly_viz_challenge/data/31304bsc.csv",
                           sep = ";", thousands='.')

# %%
poblacion_df = pd.DataFrame(poblacion_df)
poblacion_df
# Out:
#             Sexo   Edad      Provincias             Periodo     Total
# 0    Ambos sexos  Total  Total Nacional  1 de enero de 2022  47432805
# 1    Ambos sexos  Total  Total Nacional  1 de julio de 2021  47331545
# 2    Ambos sexos  Total  Total Nacional  1 de enero de 2021  47398695
# 3    Ambos sexos  Total  Total Nacional  1 de julio de 2020  47355685
# 4    Ambos sexos  Total  Total Nacional  1 de enero de 2020  47332614
# ..           ...    ...             ...                 ...       ...
# 98   Ambos sexos  Total  Total Nacional  1 de enero de 1973  34800600
# 99   Ambos sexos  Total  Total Nacional  1 de julio de 1972  34595886
# 100  Ambos sexos  Total  Total Nacional  1 de enero de 1972  34408338
# 101  Ambos sexos  Total  Total Nacional  1 de julio de 1971  34216856
# 102  Ambos sexos  Total  Total Nacional  1 de enero de 1971  34040642
#
# [103 rows x 5 columns]

# %%
poblacion_df["año"] = poblacion_df["Periodo"].str[-4:]
poblacion_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Sexo        103 non-null    object
#  1   Edad        103 non-null    object
#  2   Provincias  103 non-null    object
#  3   Periodo     103 non-null    object
#  4   Total       103 non-null    int64
#  5   año         103 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 5.0+ KB

# %%
poblacion_year = poblacion_df.groupby(['año'])[['Total']].mean().reset_index()
poblacion = poblacion_year.rename(columns={"año":"Periodo"})
poblacion = poblacion.astype('int64')
poblacion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Periodo  52 non-null     int64
#  1   Total    52 non-null     int64
# dtypes: int64(2)
# memory usage: 960.0 bytes

# %%
df = deaths.merge(poblacion, how = "inner", on = "Periodo")
df
# Out:
#                                          Causa de muerte     Sexo  \
# 0                       001-102  I-XXII.Todas las causas    Total
# 1                       001-102  I-XXII.Todas las causas    Total
# 2                       001-102  I-XXII.Todas las causas    Total
# 3                       001-102  I-XXII.Todas las causas    Total
# 4                       001-102  I-XXII.Todas las causas    Total
# ...                                                  ...      ...
# 301153  102  Otras causas externas y sus efectos tardíos  Mujeres
# 301154  102  Otras causas externas y sus efectos tardíos  Mujeres
# 301155  102  Otras causas externas y sus efectos tardíos  Mujeres
# 301156  102  Otras causas externas y sus efectos tardíos  Mujeres
# 301157  102  Otras causas externas y sus efectos tardíos  Mujeres
#
#                      Edad  Periodo  Total_x cause_code      cause_group  \
# 0        Todas las edades     2018   427721    001-102  Multiple causes
# 1          Menos de 1 año     2018     1027    001-102  Multiple causes
# 2           De 1 a 4 años     2018      240    001-102  Multiple causes
# 3           De 5 a 9 años     2018      179    001-102  Multiple causes
# 4       De 10 a 14 años       2018      198    001-102  Multiple causes
# ...                   ...      ...      ...        ...              ...
# 301153  De 75 a 79 años       1980        1        102     Single cause
# 301154  De 80 a 84 años       1980        1        102     Single cause
# 301155  De 85 a 89 años       1980        1        102     Single cause
# 301156  De 90 a 94 años       1980        0        102     Single cause
# 301157      95 y más años     1980        0        102     Single cause
#
#                                          cause_name   Total_y
# 0                           I-XXII.Todas las causas  46693630
# 1                           I-XXII.Todas las causas  46693630
# 2                           I-XXII.Todas las causas  46693630
# 3                           I-XXII.Todas las causas  46693630
# 4                           I-XXII.Todas las causas  46693630
# ...                                             ...       ...
# 301153  Otras causas externas y sus efectos tardíos  37420006
# 301154  Otras causas externas y sus efectos tardíos  37420006
# 301155  Otras causas externas y sus efectos tardíos  37420006
# 301156  Otras causas externas y sus efectos tardíos  37420006
# 301157  Otras causas externas y sus efectos tardíos  37420006
#
# [301158 rows x 9 columns]

# %%
deaths_hombres = df[(df['Sexo'] == 'Hombres') & (df['cause_name'] != 'I-XXII.Todas las causas')]
deaths_hombres["ratio"] = deaths_hombres["Total_x"]/deaths_hombres["Total_y"]
deaths_hombres_2529 = deaths_hombres[deaths_hombres['Edad'] == 'De 25 a 29 años']
deaths_hombres_2529
# Out:
#                          Causa de muerte     Sexo             Edad  Periodo  \
# 29      001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2018
# 7751    001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2017
# 15473   001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2016
# 23195   001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2015
# 30917   001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2014
# 38639   001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2013
# 46361   001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2012
# 54083   001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2011
# 61805   001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2010
# 69527   001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2009
# 77249   001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2008
# 84971   001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2007
# 92693   001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2006
# 100415  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2005
# 108137  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2004
# 115859  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2003
# 123581  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2002
# 131303  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2001
# 139025  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     2000
# 146747  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1999
# 154469  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1998
# 162191  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1997
# 169913  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1996
# 177635  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1995
# 185357  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1994
# 193079  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1993
# 200801  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1992
# 208523  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1991
# 216245  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1990
# 223967  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1989
# 231689  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1988
# 239411  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1987
# 247133  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1986
# 254855  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1985
# 262577  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1984
# 270299  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1983
# 278021  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1982
# 285743  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1981
# 293465  001-102  I-XXII.Todas las causas  Hombres  De 25 a 29 años     1980
#
#         Total_x cause_code      cause_group               cause_name  \
# 29          599    001-102  Multiple causes  I-XXII.Todas las causas
# 7751        585    001-102  Multiple causes  I-XXII.Todas las causas
# 15473       530    001-102  Multiple causes  I-XXII.Todas las causas
# 23195       578    001-102  Multiple causes  I-XXII.Todas las causas
# 30917       533    001-102  Multiple causes  I-XXII.Todas las causas
# 38639       598    001-102  Multiple causes  I-XXII.Todas las causas
# 46361       663    001-102  Multiple causes  I-XXII.Todas las causas
# 54083       739    001-102  Multiple causes  I-XXII.Todas las causas
# 61805       820    001-102  Multiple causes  I-XXII.Todas las causas
# 69527      1038    001-102  Multiple causes  I-XXII.Todas las causas
# 77249      1164    001-102  Multiple causes  I-XXII.Todas las causas
# 84971      1295    001-102  Multiple causes  I-XXII.Todas las causas
# 92693      1305    001-102  Multiple causes  I-XXII.Todas las causas
# 100415     1410    001-102  Multiple causes  I-XXII.Todas las causas
# 108137     1557    001-102  Multiple causes  I-XXII.Todas las causas
# 115859     1604    001-102  Multiple causes  I-XXII.Todas las causas
# 123581     1648    001-102  Multiple causes  I-XXII.Todas las causas
# 131303     1609    001-102  Multiple causes  I-XXII.Todas las causas
# 139025     1806    001-102  Multiple causes  I-XXII.Todas las causas
# 146747     1807    001-102  Multiple causes  I-XXII.Todas las causas
# 154469     1891    001-102  Multiple causes  I-XXII.Todas las causas
# 162191     2072    001-102  Multiple causes  I-XXII.Todas las causas
# 169913     2493    001-102  Multiple causes  I-XXII.Todas las causas
# 177635     2792    001-102  Multiple causes  I-XXII.Todas las causas
# 185357     2872    001-102  Multiple causes  I-XXII.Todas las causas
# 193079     2905    001-102  Multiple causes  I-XXII.Todas las causas
# 200801     3141    001-102  Multiple causes  I-XXII.Todas las causas
# 208523     3191    001-102  Multiple causes  I-XXII.Todas las causas
# 216245     2910    001-102  Multiple causes  I-XXII.Todas las causas
# 223967     2774    001-102  Multiple causes  I-XXII.Todas las causas
# 231689     2332    001-102  Multiple causes  I-XXII.Todas las causas
# 239411     2075    001-102  Multiple causes  I-XXII.Todas las causas
# 247133     1846    001-102  Multiple causes  I-XXII.Todas las causas
# 254855     1735    001-102  Multiple causes  I-XXII.Todas las causas
# 262577     1552    001-102  Multiple causes  I-XXII.Todas las causas
# 270299     1572    001-102  Multiple causes  I-XXII.Todas las causas
# 278021     1410    001-102  Multiple causes  I-XXII.Todas las causas
# 285743     1422    001-102  Multiple causes  I-XXII.Todas las causas
# 293465     1480    001-102  Multiple causes  I-XXII.Todas las causas
#
#          Total_y     ratio
# 29      46693630  0.000013
# 7751    46529954  0.000013
# 15473   46444986  0.000011
# 23195   46429857  0.000012
# 30917   46483661  0.000011
# 38639   46660563  0.000013
# 46361   46792309  0.000014
# 54083   46701716  0.000016
# 61805   46524552  0.000018
# 69527   46303410  0.000022
# 77249   45826053  0.000025
# 84971   45010331  0.000029
# 92693   44185245  0.000030
# 100415  43479474  0.000032
# 108137  42703313  0.000036
# 115859  42012033  0.000038
# 123581  41229395  0.000040
# 131303  40715797  0.000040
# 139025  40512284  0.000045
# 146747  40336617  0.000045
# 154469  40178757  0.000047
# 162191  40010651  0.000052
# 169913  39846310  0.000063
# 177635  39679310  0.000070
# 185357  39502921  0.000073
# 193079  39310058  0.000074
# 200801  39099638  0.000080
# 208523  38911519  0.000082
# 216245  38857027  0.000075
# 223967  38811838  0.000071
# 231689  38747942  0.000060
# 239411  38660187  0.000054
# 247133  38551568  0.000048
# 254855  38437427  0.000045
# 262577  38289071  0.000041
# 270299  38125207  0.000041
# 278021  37934490  0.000037
# 285743  37699923  0.000038
# 293465  37420006  0.000040

# %%
deaths_hombres_grupos = df[(df['Sexo'] == 'Hombres') & (df['cause_name'] != 'XX.Causas externas de mortalidad') & (df['cause_group'] == 'Single cause') & (df['Periodo'] < 1996) &  (df['Periodo'] > 1987)]
deaths_hombres_grupos["ratio"] = deaths_hombres_grupos["Total_x"]/deaths_hombres_grupos["Total_y"]
deaths_hombres_2529_grupos = deaths_hombres_grupos[deaths_hombres_grupos['Edad'] == 'De 25 a 29 años']
deaths_hombres_2529_grupos
# Out:
#                                           Causa de muerte     Sexo  \
# 177767         001  Enfermedades infecciosas intestinales  Hombres
# 177833            002  Tuberculosis y sus efectos tardíos  Hombres
# 177899                      003  Enfermedad meningocócica  Hombres
# 177965                                    004  Septicemia  Hombres
# 178031                              005  Hepatitis vírica  Hombres
# ...                                                   ...      ...
# 239081            098  Suicidio y lesiones autoinfligidas  Hombres
# 239147                        099  Agresiones (homicidio)  Hombres
# 239213           100  Eventos de intención no determinada  Hombres
# 239279  101  Complicaciones de la atención médica y qu...  Hombres
# 239345   102  Otras causas externas y sus efectos tardíos  Hombres
#
#                    Edad  Periodo  Total_x cause_code   cause_group  \
# 177767  De 25 a 29 años     1995        0        001  Single cause
# 177833  De 25 a 29 años     1995        9        002  Single cause
# 177899  De 25 a 29 años     1995        0        003  Single cause
# 177965  De 25 a 29 años     1995        6        004  Single cause
# 178031  De 25 a 29 años     1995        7        005  Single cause
# ...                 ...      ...      ...        ...           ...
# 239081  De 25 a 29 años     1988      183        098  Single cause
# 239147  De 25 a 29 años     1988       34        099  Single cause
# 239213  De 25 a 29 años     1988       11        100  Single cause
# 239279  De 25 a 29 años     1988        3        101  Single cause
# 239345  De 25 a 29 años     1988        1        102  Single cause
#
#                                                cause_name   Total_y  \
# 177767              Enfermedades infecciosas intestinales  39679310
# 177833                 Tuberculosis y sus efectos tardíos  39679310
# 177899                           Enfermedad meningocócica  39679310
# 177965                                         Septicemia  39679310
# 178031                                   Hepatitis vírica  39679310
# ...                                                   ...       ...
# 239081                 Suicidio y lesiones autoinfligidas  38747942
# 239147                             Agresiones (homicidio)  38747942
# 239213                Eventos de intención no determinada  38747942
# 239279  Complicaciones de la atención médica y quirúrgica  38747942
# 239345        Otras causas externas y sus efectos tardíos  38747942
#
#                ratio
# 177767  0.000000e+00
# 177833  2.268185e-07
# 177899  0.000000e+00
# 177965  1.512123e-07
# 178031  1.764144e-07
# ...              ...
# 239081  4.722831e-06
# 239147  8.774660e-07
# 239213  2.838860e-07
# 239279  7.742347e-08
# 239345  2.580782e-08
#
# [816 rows x 10 columns]

# %% [markdown]
# ## Lets make some transformations
#
# Eventhough the dataset is pretty clean, the information is completely denormalized as you could see. For that matter a collection of methods (functions) are available in order to generate the tables you might need:
#
# - `row_filter(df, cat_var, cat_values)` => Filter rows by any value or group of values in a categorical variable.
#
# - `nrow_filter(df, cat_var, cat_values)` => The same but backwards.
#
# - `groupby_sum(df, group_vars, agg_var='Total', sort_var='Total')` => Add deaths by a certain variable.
#
# - `pivot_table(df, col, x_axis, value='Total')`=> Make some pivot tables, you might need them...
#
# __NOTE:__ be aware that the filtering methods can perform a filter at a time. Feel free to perform the filter you need in any way you want or feel confortable with.

# %%
# Example 1
'''
dataset = mod.row_filter(deaths, 'Sexo', ['Total'])
dataset = mod.row_filter(dataset, 'Edad', ['Todas las edades'])
dataset.head()
'''

# %%
# Example 2
'''
group = ['cause_code','Periodo']
dataset = mod.groupby_sum(deaths, group)
dataset.head()
'''

# %%
# Example 3
'''
dataset = mod.pivot_table(dataset, 'cause_code', 'Periodo')
dataset.head()
'''

# %% [markdown]
# ## ...and finally, show me some insights with Plotly!!!

# %%
# Cufflinks histogram
'''
dataset_column.iplot(kind='hist',
                     title='VIZ TITLE',
                     yTitle='AXIS TITLE',
                     xTitle='AXIS TITLE')
'''

# %%
# Cufflinks bar plot
'''
dataset_bar.iplot(kind='bar',
                  x='VARIABLE',
                  xTitle='AXIS TITLE',
                  yTitle='AXIS TITLE',
                  title='VIZ TITLE')
'''

# %%
deaths_hombres.iplot(kind='bar',
                  x='Periodo',
               y = 'ratio',
                  xTitle='año',
                  yTitle='ratio muertes',
                  title='muertes en el tiempo')
# Out:
# <div>                            <div id="6ec3a83b-2700-4523-aa56-dc70b10f86f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("6ec3a83b-2700-4523-aa56-dc70b10f86f2")) {                    Plotly.newPlot(                        "6ec3a83b-2700-4523-aa56-dc70b10f86f2",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"ratio","orientation":"v","text":"","x":[2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2018,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2017,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2016,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2015,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2014,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2013,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2012,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2011,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2010,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2009,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2008,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2007,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,2006,2005,2005,2005,2005,2005,2005,2005,2005,2005,2005,2005,2005,2005,2005,2005,2005,2005,2005,2005,2005,2005,2005,2004,2004,2004,2004,2004,2004,2004,2004,2004,2004,2004,2004,2004,2004,2004,2004,2004,2004,2004,2004,2004,2004,2003,2003,2003,2003,2003,2003,2003,2003,2003,2003,2003,2003,2003,2003,2003,2003,2003,2003,2003,2003,2003,2003,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2002,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2001,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,2000,1999,1999,1999,1999,1999,1999,1999,1999,1999,1999,1999,1999,1999,1999,1999,1999,1999,1999,1999,1999,1999,1999,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1998,1997,1997,1997,1997,1997,1997,1997,1997,1997,1997,1997,1997,1997,1997,1997,1997,1997,1997,1997,1997,1997,1997,1996,1996,1996,1996,1996,1996,1996,1996,1996,1996,1996,1996,1996,1996,1996,1996,1996,1996,1996,1996,1996,1996,1995,1995,1995,1995,1995,1995,1995,1995,1995,1995,1995,1995,1995,1995,1995,1995,1995,1995,1995,1995,1995,1995,1994,1994,1994,1994,1994,1994,1994,1994,1994,1994,1994,1994,1994,1994,1994,1994,1994,1994,1994,1994,1994,1994,1993,1993,1993,1993,1993,1993,1993,1993,1993,1993,1993,1993,1993,1993,1993,1993,1993,1993,1993,1993,1993,1993,1992,1992,1992,1992,1992,1992,1992,1992,1992,1992,1992,1992,1992,1992,1992,1992,1992,1992,1992,1992,1992,1992,1991,1991,1991,1991,1991,1991,1991,1991,1991,1991,1991,1991,1991,1991,1991,1991,1991,1991,1991,1991,1991,1991,1990,1990,1990,1990,1990,1990,1990,1990,1990,1990,1990,1990,1990,1990,1990,1990,1990,1990,1990,1990,1990,1990,1989,1989,1989,1989,1989,1989,1989,1989,1989,1989,1989,1989,1989,1989,1989,1989,1989,1989,1989,1989,1989,1989,1988,1988,1988,1988,1988,1988,1988,1988,1988,1988,1988,1988,1988,1988,1988,1988,1988,1988,1988,1988,1988,1988,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1987,1986,1986,1986,1986,1986,1986,1986,1986, ...

# %%
deaths_hombres_2529.iplot(kind='bar',
                  x='Periodo',
               y = 'ratio',
                  xTitle='año',
                  yTitle='ratio muertes',
                  title='muertes en el tiempo')
# Out:
# <div>                            <div id="b795a061-6add-4611-9d93-eebebd263531" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("b795a061-6add-4611-9d93-eebebd263531")) {                    Plotly.newPlot(                        "b795a061-6add-4611-9d93-eebebd263531",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"ratio","orientation":"v","text":"","x":[2018,2017,2016,2015,2014,2013,2012,2011,2010,2009,2008,2007,2006,2005,2004,2003,2002,2001,2000,1999,1998,1997,1996,1995,1994,1993,1992,1991,1990,1989,1988,1987,1986,1985,1984,1983,1982,1981,1980],"y":[1.282830227592072e-05,1.2572546278468274e-05,1.141135019396927e-05,1.244888606915158e-05,1.1466394611216186e-05,1.2815961950566263e-05,1.4168995165423447e-05,1.582382968540171e-05,1.762510254800519e-05,2.241735543883269e-05,2.540039832799914e-05,2.8771172555918328e-05,2.9534746271068544e-05,3.242909516338675e-05,3.6460871314598e-05,3.817953775290998e-05,3.997148151215898e-05,3.951783137144534e-05,4.4579071374993326e-05,4.479800574252422e-05,4.706467151285939e-05,5.178621062676536e-05,6.256539187693916e-05,7.036412679555163e-05,7.270348438283843e-05,7.38996620152532e-05,8.033322456847298e-05,8.200656468846667e-05,7.488992917548736e-05,7.147303871566195e-05,6.018384150569855e-05,5.3672787459615754e-05,4.788391486437076e-05,4.513829710818053e-05,4.053375962033657e-05,4.1232563012707054e-05,3.7169341145748894e-05,3.771890992986909e-05,3.955103588171525e-05],"type":"bar"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks": ...

# %%
deaths_hombres_2529_grupos.iplot(kind='bar',
                  x='cause_name',
               y = 'ratio',
                  xTitle='año',
                  yTitle='ratio muertes',
                  title='muertes en el tiempo')
# Out:
# <div>                            <div id="383be065-7b44-4915-b662-3c1da483c109" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("383be065-7b44-4915-b662-3c1da483c109")) {                    Plotly.newPlot(                        "383be065-7b44-4915-b662-3c1da483c109",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"ratio","orientation":"v","text":"","x":["Enfermedades infecciosas intestinales","Tuberculosis y sus efectos tard\u00edos","Enfermedad meningoc\u00f3cica","Septicemia","Hepatitis v\u00edrica","SIDA","VIH+ (portador, evidencias de laboratorio del VIH, ...)","Resto de enfermedades infecciosas y parasitarias y sus efectos tard\u00edos","Tumor maligno del labio, de la cavidad bucal y de la faringe","Tumor maligno del es\u00f3fago","Tumor maligno del est\u00f3mago","Tumor maligno del colon","Tumor maligno del recto, de la porci\u00f3n rectosigmoide y del ano","Tumor maligno del h\u00edgado y v\u00edas biliares intrahep\u00e1ticas","Tumor maligno del p\u00e1ncreas","Otros tumores malignos digestivos","Tumor maligno de la laringe","Tumor maligno de la tr\u00e1quea, de los bronquios y del pulm\u00f3n","Otros tumores malignos respiratorios e intrator\u00e1cicos","Tumores malignos del hueso y de los cart\u00edlagos articulares","Melanoma maligno de la piel","Otros tumores malignos de la piel y de los tejidos blandos","Tumor maligno de la mama","Tumor maligno del cuello del \u00fatero","Tumor maligno de otras partes del \u00fatero","Tumor maligno del ovario","Tumores malignos de otros \u00f3rganos genitales femeninos","Tumor maligno de la pr\u00f3stata","Tumores malignos de otros \u00f3rganos genitales masculinos","Tumor maligno del ri\u00f1\u00f3n, excepto pelvis renal","Tumor maligno de la vejiga","Otros tumores malignos de las v\u00edas urinarias","Tumor maligno del enc\u00e9falo","Otros tumores malignos neurol\u00f3gicos y endocrinos","Tumor maligno de sitios mal definidos, secundarios y de sitios no especificados","Tumores malignos del tejido linf\u00e1tico, de los \u00f3rganos hematopoy\u00e9ticos y de tejidos afines, excepto leucemia","Leucemia","Tumores in situ","Tumores benignos","S\u00edndrome mielodispl\u00e1sico","Otros tumores de comportamiento incierto o desconocido","Enfermedades de la sangre y de los \u00f3rganos hematopoy\u00e9ticos","Ciertos trastornos que afectan al mecanismo de la inmunidad","Diabetes mellitus","Otras enfermedades endocrinas, nutricionales y metab\u00f3licas","Trastornos mentales org\u00e1nicos, senil y presenil","Trastornos mentales debidos al uso de alcohol","Trastornos mentales debidos al uso de drogas (drogodependencia, toxicoman\u00eda)","Otros trastornos mentales y del comportamiento","Meningitis (otras en 003)","Enfermedad de Alzheimer","Otras enfermedades del sistema nervioso y de los \u00f3rganos de los sentidos","Enfermedades card\u00edacas reum\u00e1ticas cr\u00f3nicas","Enfermedades hipertensivas","Infarto agudo de miocardio","Otras enfermedades isqu\u00e9micas del coraz\u00f3n","Insuficiencia card\u00edaca","Otras enfermedades del coraz\u00f3n","Enfermedades cerebrovasculares","Aterosclerosis","Otras enfermedades de los vasos sangu\u00edneos","Influenza (gripe) (incluye gripe aviar y gripe A)","Neumon\u00eda","Enfermedades cr\u00f3nicas de las v\u00edas respiratorias inferiores (excepto asma)","Asma","Insuficiencia respiratoria","Otras enfermedades del sistema respiratorio","\u00dalcera de est\u00f3mago, duodeno y yeyuno","Enteritis y colitis no infecciosas","Enfermedad vascular intestinal","Cirrosis y otras enfermedades cr\u00f3nicas del h\u00edgado","Otras enfermedades del sistema digestivo","XII.Enfermedades de la piel y del tejido subcut\u00e1neo","Artritis reumatoide y osteoartrosis","Osteoporosis y fractura patol\u00f3gica","Otras enfermedades del sistema osteomuscular y del tejido conjuntivo","Enfermedades del ri\u00f1\u00f3n y del ur\u00e9ter","Enfermedades de los \u00f3rganos genitales ma ...

# %%
death_l20y.iplot(kind='bar',
                  x='cause_name',
               y = 'Total',
                  xTitle='causa',
                  yTitle='muertes',
                  title='muertes por cause después de 1996')

# %%
death_f20y.iplot(kind='bar',
                  x='cause_name',
               y = 'Total',
                  xTitle='causa',
                  yTitle='muertes',
                  title='muertes por cause antes 1996')

# %%
death_l20y_Mujeres = death[death.Sexo == 'Mujeres']
death_l20y_Hombres = death[death.Sexo == 'Hombres']

# %%
death_l20y_Mujeres.iplot(kind='bar',
                  x='cause_name',
               y = 'Total',
                  xTitle='causa',
                  yTitle='muertes',
                  title='muertes por cause después 1996 Mujeres')
# Out:
# <div>                            <div id="1ce3673c-68c6-4e2e-820a-5a4eae3071d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("1ce3673c-68c6-4e2e-820a-5a4eae3071d3")) {                    Plotly.newPlot(                        "1ce3673c-68c6-4e2e-820a-5a4eae3071d3",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"Total","orientation":"v","text":"","x":["I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitari ...

# %%
death_l20y_Hombres.iplot(kind='bar',
                  x='cause_name',
               y = 'Total',
                  xTitle='causa',
                  yTitle='muertes',
                  title='muertes por cause después 1996 hombres')
# Out:
# <div>                            <div id="f2842513-6aa1-45e0-afaf-9821588269b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("f2842513-6aa1-45e0-afaf-9821588269b3")) {                    Plotly.newPlot(                        "f2842513-6aa1-45e0-afaf-9821588269b3",                        [{"marker":{"color":"rgba(255, 153, 51, 0.6)","line":{"color":"rgba(255, 153, 51, 1.0)","width":1}},"name":"Total","orientation":"v","text":"","x":["I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitarias","I.Enfermedades infecciosas y parasitari ...

# %%
# Cufflinks line plot
'''
dataset_line.iplot(kind='line',
                   x='VARIABLE',
                   xTitle='AXIS TITLE',
                   yTitle='AXIS TITLE',
                   title='VIZ TITLE')
'''

# %%
# Cufflinks scatter plot
'''
dataset_scatter.iplot(x='VARIABLE', 
                      y='VARIABLE', 
                      categories='VARIABLE',
                      xTitle='AXIS TITLE', 
                      yTitle='AXIS TITLE',
                      title='VIZ TITLE')
'''
